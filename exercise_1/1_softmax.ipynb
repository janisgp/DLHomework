# %% [markdown]
# # Linear Classification with Softmax Loss
#
# In this exercise you will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import time
import random
import math
import numpy as np
from dl4cv.model_savers import save_softmax_classifier
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## CIFAR-10 Data Loading and Preprocessing
#
# To your convenience, we have taken care of all the input handling. Nevertheless, you should go through the code line by line so that you understand the general preprocessing pipeline.
# The whole datasat is loaded, then subdivided into a training, validation and test dataset (the last one is different from the final evaluation dataset on our server!).
# Before proceeding you should *always* take a look at some samples of your dataset, which is already implemented for you. This way you can make sure that the data input/preprocessing has worked as intended and you can get a feeling for the dataset.

# %%
from dl4cv.data_utils import load_CIFAR10
# Load the raw CIFAR-10 data
cifar10_dir = 'datasets/'
X, y = load_CIFAR10(cifar10_dir)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y_hat, cls in enumerate(classes):
    idxs = np.flatnonzero(y == y_hat)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y_hat + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Split the data into train, val, and test sets. In addition we will
# create a small development set as a subset of the data set;
# we can use this for development so our code runs faster.
num_training = 48000
num_validation = 1000
num_test = 1000
num_dev = 500

assert (num_training + num_validation + num_test) == 50000, 'You have not provided a valid data split.'

# Our training set will be the first num_train points from the original
# training set.
mask = range(num_training)
X_train = X[mask]
y_train = y[mask]

# Our validation set will be num_validation points from the original
# training set.
mask = range(num_training, num_training + num_validation)
X_val = X[mask]
y_val = y[mask]

# We use a small subset of the training set as our test set.
mask = range(num_training + num_validation, num_training + num_validation + num_test)
X_test = X[mask]
y_test = y[mask]

# We will also make a development set, which is a small subset of
# the training set. This way the development cycle is faster.
mask = np.random.choice(num_training, num_dev, replace=False)
X_dev = X_train[mask]
y_dev = y_train[mask]

# %%
# Preprocessing: reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_val = np.reshape(X_val, (X_val.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

# As a sanity check, print out the shapes of the data
print('Training data shape: ', X_train.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
print('dev data shape: ', X_dev.shape)
# Out:
# Training data shape:  (48000, 3072)
# Validation data shape:  (1000, 3072)
# Test data shape:  (1000, 3072)
# dev data shape:  (500, 3072)

# %%
# Preprocessing: subtract the mean image
# first: compute the image mean based on the training data
mean_image = np.mean(X_train, axis=0)
print(mean_image[:10]) # print a few of the elements
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # visualize the mean image
plt.show()
# Out:
# [ 130.64297917  135.92841667  132.4100625   130.0744375   135.3130625
#   131.70479167  131.0373125   136.18741667  132.48804167  131.65420833]

# %%
# second: subtract the mean image from train and test data
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image
X_dev -= mean_image

# %%
# third: append the bias dimension of ones (i.e. bias trick) so that our classifier
# only has to worry about optimizing a single weight matrix W.
X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])

print(X_train.shape, X_val.shape, X_test.shape, X_dev.shape)
# Out:
# (48000, 3073) (1000, 3073) (1000, 3073) (500, 3073)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `dl4cv/classifiers/softmax.py`.
# You will implement the gradient of the loss function with respect to the classifier's weights. We suggest that you first derive these expressions on paper.

# %% [markdown]
# ### Naive Implementation
# First implement the naive softmax loss function with nested loops.
# Open the file `dl4cv/classifiers/softmax.py` and implement the softmax_loss_naive function.
# Running this method might take a while...

# %%
from dl4cv.classifiers.softmax import softmax_loss_naive
from dl4cv.classifiers.softmax import softmax_loss_vectorized

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_vectorized(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.333616
# sanity check: 2.302585

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Inline Question</h3>
#     <p>Why do we expect our loss to be close to -log(0.1)? Explain briefly.</p>
#     <p>Answer: Because we initialize random weightswhich gives us roughly a 10% probability to correctly predict an example.</p>
# </div>

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_vectorized(W, X_dev, y_dev, 0.0)

# We use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from dl4cv.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_vectorized(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, num_checks=3)

# Do another gradient check with regularization
loss, grad = softmax_loss_vectorized(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_vectorized(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, num_checks=3)

# Again, running this might take a while!
# Out:
# numerical: -0.428363 analytic: -0.428363, relative error: 9.673654e-08
# numerical: -1.345733 analytic: -1.345733, relative error: 5.226439e-08
# numerical: 3.658836 analytic: 3.658836, relative error: 1.945349e-08
# numerical: 1.193669 analytic: 1.193669, relative error: 2.299708e-08
# numerical: -0.212764 analytic: -0.212764, relative error: 1.418181e-07
# numerical: 0.715733 analytic: 0.715734, relative error: 8.098044e-08

# %% [markdown]
# ### Vectorized Implementation
# Now that we have a naive implementation of the softmax loss function and its gradient, implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be much faster.

# %%
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from dl4cv.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# We use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.335474e+00 computed in 33.717539s
# vectorized loss: 2.335474e+00 computed in 0.011004s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Inline Question</h3>
#     <p>When you compute the softmax distribution, you are dividing by a sum of exponentials, i.e. potentially very large numbers, which can be numerically unstable. Do you see a way to avoid this problem?
# </p>
#     <p>(Hint: exploit properties of the exponential function to arrive at an expression that is mathematically the same, but numerically more stable)</p>
#     <p>Answer: We could add a constant in the argument of every exponential function. This would still yield the same result since it cancels out overall. We could e.g. choose this example to be the mean of all predictions to ensure the arguments are scattered around zero (assuming relatively small variation)</p>
# </div>

# %% [markdown]
# ### Stochastic Gradient Descent
#
# We now have vectorized and efficient expressions for the loss, the gradient and our gradient matches the numerical gradient. We are therefore ready to do SGD to minimize the loss.

# %%
# In the file linear_classifier.py, implement SGD in the function
# LinearClassifier.train() and then run it with the code below.
from dl4cv.classifiers import Softmax
softmax = Softmax()
tic = time.time()
loss_hist = softmax.train(X_train, y_train, learning_rate=1e-7, reg=1e5,
                      num_iters=1500, verbose=True)
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 3063.066203
# iteration 100 / 1500: loss 55.868984
# iteration 200 / 1500: loss 3.114347
# iteration 300 / 1500: loss 2.176907
# iteration 400 / 1500: loss 2.210768
# iteration 500 / 1500: loss 2.199720
# iteration 600 / 1500: loss 2.180222
# iteration 700 / 1500: loss 2.204585
# iteration 800 / 1500: loss 2.201832
# iteration 900 / 1500: loss 2.218796
# iteration 1000 / 1500: loss 2.216377
# iteration 1100 / 1500: loss 2.167071
# iteration 1200 / 1500: loss 2.176628
# iteration 1300 / 1500: loss 2.184322
# iteration 1400 / 1500: loss 2.197378
# That took 8.792617s

# %%
# A useful debugging strategy is to plot the loss as a function of
# iteration number:
plt.figure(figsize=(6,5))
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# Write the LinearClassifier.predict function and evaluate the performance on both the
# training and validation set
y_train_pred = softmax.predict(X_train)
print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
y_val_pred = softmax.predict(X_val)
print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
# Out:
# training accuracy: 0.291708
# validation accuracy: 0.286000

# %% [markdown]
# ### Training your Softmax Classifier
# Use the validation set to tune hyperparameters (regularization strength and learning rate). You should experiment with different ranges for the learning rates and regularization strengths; if you are careful you should be able to get a classification accuracy of over 0.35 on the validation set.

# %%
from dl4cv.classifiers import Softmax

best_val = -1
best_softmax = None

learning_rate = 11e-6
regularization_strength = 1

num_iters = 50

param_learning_rate_learning = 0.000001
param_learning_rate_regularization = 0.01

while best_val < 0.4:
    
    softmax = Softmax()
    
    #compute derivatives w.r.t. params
    #dParam = learning_rate*0.1
    #softmax.train(X_train,y_train,0.5*learning_rate+dParam, regularization_strength,num_iters=num_iters,verbose=False)
    #val1 = np.mean(y_val == softmax.predict(X_val))
    #softmax = Softmax()
    #softmax.train(X_train,y_train,0.5*learning_rate-dParam, regularization_strength,num_iters=num_iters,verbose=False)
    #val2 = np.mean(y_val == softmax.predict(X_val))
    
    #dLearning = (val1-val2)/dParam*learning_rate*param_learning_rate_learning
    
    softmax= Softmax()
    
    dParam = regularization_strength*0.5
    softmax.train(X_train,y_train,learning_rate, regularization_strength,num_iters=num_iters,verbose=False)
    val1 = np.mean(y_val == softmax.predict(X_val))
    softmax = Softmax()
    softmax.train(X_train,y_train,learning_rate, regularization_strength-dParam,num_iters=num_iters,verbose=False)
    val2 = np.mean(y_val == softmax.predict(X_val))
    
    dReg = (val1-val2)/dParam*param_learning_rate_regularization
    
    #learning_rate += dLearning
    regularization_strength -= dReg
    
    softmax = Softmax()
    
    softmax.train(X_train,y_train,learning_rate, regularization_strength,num_iters=num_iters,verbose=False)
    current_val = np.mean(y_val == softmax.predict(X_val))
    
    print("learning rate: %f || regularization strength: %f || validation accuracy: %f" % (learning_rate,regularization_strength,current_val))
# Out:
# learning rate: 0.000011 || regularization strength: 1.000500 || validation accuracy: 0.248000
# learning rate: 0.000011 || regularization strength: 1.000780 || validation accuracy: 0.282000
# learning rate: 0.000011 || regularization strength: 1.001180 || validation accuracy: 0.228000
# learning rate: 0.000011 || regularization strength: 1.001919 || validation accuracy: 0.286000
# learning rate: 0.000011 || regularization strength: 1.001979 || validation accuracy: 0.254000
# learning rate: 0.000011 || regularization strength: 1.001679 || validation accuracy: 0.257000
# learning rate: 0.000011 || regularization strength: 1.002817 || validation accuracy: 0.278000
# learning rate: 0.000011 || regularization strength: 1.003116 || validation accuracy: 0.214000
# learning rate: 0.000011 || regularization strength: 1.003535 || validation accuracy: 0.264000
# learning rate: 0.000011 || regularization strength: 1.002539 || validation accuracy: 0.243000
# learning rate: 0.000011 || regularization strength: 1.003616 || validation accuracy: 0.245000
# learning rate: 0.000011 || regularization strength: 1.003277 || validation accuracy: 0.245000
# learning rate: 0.000011 || regularization strength: 1.003935 || validation accuracy: 0.253000
# learning rate: 0.000011 || regularization strength: 1.004513 || validation accuracy: 0.283000
# learning rate: 0.000011 || regularization strength: 1.004174 || validation accuracy: 0.253000
# learning rate: 0.000011 || regularization strength: 1.003915 || validation accuracy: 0.255000
# learning rate: 0.000011 || regularization strength: 1.003696 || validation accuracy: 0.225000
# learning rate: 0.000011 || regularization strength: 1.002660 || validation accuracy: 0.248000
# learning rate: 0.000011 || regularization strength: 1.002261 || validation accuracy: 0.254000
# learning rate: 0.000011 || regularization strength: 1.002341 || validation accuracy: 0.261000
# learning rate: 0.000011 || regularization strength: 1.001184 || validation accuracy: 0.270000
# learning rate: 0.000011 || regularization strength: 1.001303 || validation accuracy: 0.274000
# learning rate: 0.000011 || regularization strength: 1.001983 || validation accuracy: 0.258000
# learning rate: 0.000011 || regularization strength: 1.000965 || validation accuracy: 0.292000
# learning rate: 0.000011 || regularization strength: 1.001664 || validation accuracy: 0.317000
# learning rate: 0.000011 || regularization strength: 1.002203 || validation accuracy: 0.225000
# learning rate: 0.000011 || regularization strength: 1.001644 || validation accuracy: 0.265000
# learning rate: 0.000011 || regularization strength: 1.001624 || validation accuracy: 0.256000
# learning rate: 0.000011 || regularization strength: 1.000945 || validation accuracy: 0.276000
# learning rate: 0.000011 || regularization strength: 1.000905 || validation accuracy: 0.246000
# learning rate: 0.000011 || regularization strength: 1.000805 || validation accuracy: 0.264000
# learning rate: 0.000011 || regularization strength: 1.001445 || validation accuracy: 0.222000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-b19eba3dffac> in <module>()
#      29
#      30     dParam = regularization_strength*0.5
# ---> 31     softmax.train(X_train,y_train,learning_rate, regularization_strength,num_iters=num_iters,verbose=False)
#      32     val1 = np.mean(y_val == softmax.predict(X_val))
#      33     softmax = Softmax()
#
# C:\Users\Janis\Homework\Deeplearning\HW1\dl4cv\exercise_1\dl4cv\classifiers\linear_classifier.py in train(self, X, y, learning_rate, reg, num_iters, batch_size, verbose)
#      63
#      64             # evaluate loss and gradient
# ---> 65             loss, grad = self.loss(X_batch, y_batch, reg)
#      66             loss_history.append(loss)
#      67
#
# C:\Users\Janis\Homework\Deeplearning\HW1\dl4cv\exercise_1\dl4cv\classifiers\linear_classifier.py in loss(self, X_batch, y_batch, reg)
#     133
#     134     def loss(self, X_batch, y_batch, reg):
# --> 135         return softmax_loss_vectorized(self.W, X_batch, y_batch, reg)
#     136
#
# C:\Users\Janis\Homework\Deeplearning\HW1\dl4cv\exercise_1\dl4cv\classifiers\softmax.py in softmax_loss_vectorized(W, X, y, reg)
#     132
#     133     #sum of the partial derivatives of the soft max loss function over the training examples
# --> 134     dW = (-1)*np.matmul(X.T,(correctPredictionMatrix - softmax).T)/N
#     135
#     136     #add regularization term
#
# KeyboardInterrupt:

# %%
from dl4cv.classifiers import Softmax

# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1
best_softmax = None
all_classifiers = []
#learning_rates = [1e-9, 3e-9, 6e-9, 1e-8, 5e-8, 1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 3-5, 6e-5]
learning_rates = [4e-7, 5e-7,6e-7,8e-7,9e-7,1e-6,2e-6,3e-6,4e-6, 5e-6,6e-6,7e-6,8e-6,9e-6, 1e-5]
regularization_strengths = [1e-4, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4]

################################################################################
# TODO:                                                                        #
# Write code that chooses the best hyperparameters by tuning on the validation #
# set. For each combination of hyperparameters, train a classifier on the      #
# training set, compute its accuracy on the training and validation sets, and  #
# store these numbers in the results dictionary. In addition, store the best   #
# validation accuracy in best_val and the Softmax object that achieves this    #
# accuracy in best_softmax.                                                    #
#                                                                              #
# Hint: You should use a small value for num_iters as you develop your         #
# validation code so that the classifiers don't take much time to train;       # 
# once you are confident that your validation code works, you should rerun     #
# the validation code with a larger value for num_iters.                       #
################################################################################

for learning_rate in learning_rates:
    for regularization_strength in regularization_strengths:
        
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=learning_rate, reg= regularization_strength, 
                      num_iters=2000, verbose=False)
        accuracy_training = np.mean(y_train == softmax.predict(X_train))
        accuracy_validation = np.mean(y_val == softmax.predict(X_val))
        results[(learning_rate, regularization_strength)] = \
            (accuracy_training, accuracy_validation)
        
        if accuracy_validation > best_val:
            best_val = accuracy_validation
            best_softmax = softmax
        
        print("done with learn: %f and reg: %f with acc: %f" %(learning_rate, regularization_strength,accuracy_validation))

################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for (lr, reg) in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
          lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during validation: %f' % best_val)
# Out:
# done with learn: 0.000000 and reg: 0.000100 with acc: 0.321000
# done with learn: 0.000000 and reg: 0.001000 with acc: 0.331000
# done with learn: 0.000000 and reg: 0.010000 with acc: 0.320000
# done with learn: 0.000000 and reg: 0.100000 with acc: 0.308000
# done with learn: 0.000000 and reg: 1.000000 with acc: 0.321000
# done with learn: 0.000000 and reg: 10.000000 with acc: 0.334000
# done with learn: 0.000000 and reg: 100.000000 with acc: 0.323000
# done with learn: 0.000000 and reg: 1000.000000 with acc: 0.385000
# done with learn: 0.000000 and reg: 10000.000000 with acc: 0.333000
# done with learn: 0.000000 and reg: 0.000100 with acc: 0.329000
# done with learn: 0.000000 and reg: 0.001000 with acc: 0.316000
# done with learn: 0.000000 and reg: 0.010000 with acc: 0.335000
# done with learn: 0.000000 and reg: 0.100000 with acc: 0.323000
# done with learn: 0.000000 and reg: 1.000000 with acc: 0.343000
# done with learn: 0.000000 and reg: 10.000000 with acc: 0.342000
# done with learn: 0.000000 and reg: 100.000000 with acc: 0.334000
# done with learn: 0.000000 and reg: 1000.000000 with acc: 0.376000
# done with learn: 0.000000 and reg: 10000.000000 with acc: 0.343000
# done with learn: 0.000001 and reg: 0.000100 with acc: 0.337000
# done with learn: 0.000001 and reg: 0.001000 with acc: 0.316000
# done with learn: 0.000001 and reg: 0.010000 with acc: 0.324000
# done with learn: 0.000001 and reg: 0.100000 with acc: 0.330000
# done with learn: 0.000001 and reg: 1.000000 with acc: 0.336000
# done with learn: 0.000001 and reg: 10.000000 with acc: 0.332000
# done with learn: 0.000001 and reg: 100.000000 with acc: 0.343000
# done with learn: 0.000001 and reg: 1000.000000 with acc: 0.384000
# done with learn: 0.000001 and reg: 10000.000000 with acc: 0.342000
# done with learn: 0.000001 and reg: 0.000100 with acc: 0.346000
# done with learn: 0.000001 and reg: 0.001000 with acc: 0.359000
# done with learn: 0.000001 and reg: 0.010000 with acc: 0.316000
# done with learn: 0.000001 and reg: 0.100000 with acc: 0.352000
# done with learn: 0.000001 and reg: 1.000000 with acc: 0.349000
# done with learn: 0.000001 and reg: 10.000000 with acc: 0.353000
# done with learn: 0.000001 and reg: 100.000000 with acc: 0.360000
# done with learn: 0.000001 and reg: 1000.000000 with acc: 0.402000
# done with learn: 0.000001 and reg: 10000.000000 with acc: 0.331000
# done with learn: 0.000001 and reg: 0.000100 with acc: 0.358000
# done with learn: 0.000001 and reg: 0.001000 with acc: 0.360000
# done with learn: 0.000001 and reg: 0.010000 with acc: 0.360000
# done with learn: 0.000001 and reg: 0.100000 with acc: 0.351000
# done with learn: 0.000001 and reg: 1.000000 with acc: 0.361000
# done with learn: 0.000001 and reg: 10.000000 with acc: 0.350000
# done with learn: 0.000001 and reg: 100.000000 with acc: 0.363000
# done with learn: 0.000001 and reg: 1000.000000 with acc: 0.391000
# done with learn: 0.000001 and reg: 10000.000000 with acc: 0.350000
# done with learn: 0.000001 and reg: 0.000100 with acc: 0.353000
# done with learn: 0.000001 and reg: 0.001000 with acc: 0.361000
# done with learn: 0.000001 and reg: 0.010000 with acc: 0.365000
# done with learn: 0.000001 and reg: 0.100000 with acc: 0.337000
# done with learn: 0.000001 and reg: 1.000000 with acc: 0.346000
# done with learn: 0.000001 and reg: 10.000000 with acc: 0.380000
# done with learn: 0.000001 and reg: 100.000000 with acc: 0.379000
# done with learn: 0.000001 and reg: 1000.000000 with acc: 0.390000
# done with learn: 0.000001 and reg: 10000.000000 with acc: 0.355000
# done with learn: 0.000002 and reg: 0.000100 with acc: 0.363000
# done with learn: 0.000002 and reg: 0.001000 with acc: 0.363000
# done with learn: 0.000002 and reg: 0.010000 with acc: 0.368000
# done with learn: 0.000002 and reg: 0.100000 with acc: 0.370000
# done with learn: 0.000002 and reg: 1.000000 with acc: 0.356000
# done with learn: 0.000002 and reg: 10.000000 with acc: 0.369000
# done with learn: 0.000002 and reg: 100.000000 with acc: 0.399000
# done with learn: 0.000002 and reg: 1000.000000 with acc: 0.372000
# done with learn: 0.000002 and reg: 10000.000000 with acc: 0.333000
# done with learn: 0.000003 and reg: 0.000100 with acc: 0.367000
# done with learn: 0.000003 and reg: 0.001000 with acc: 0.381000
# done with learn: 0.000003 and reg: 0.010000 with acc: 0.373000
# done with learn: 0.000003 and reg: 0.100000 with acc: 0.364000
# done with learn: 0.000003 and reg: 1.000000 with acc: 0.363000
# done with learn: 0.000003 and reg: 10.000000 with acc: 0.365000
# done with learn: 0.000003 and reg: 100.000000 with acc: 0.405000
# done with learn: 0.000003 and reg: 1000.000000 with acc: 0.391000
# done with learn: 0.000003 and reg: 10000.000000 with acc: 0.340000
# done with learn: 0.000004 and reg: 0.000100 with acc: 0.371000
# done with learn: 0.000004 and reg: 0.001000 with acc: 0.399000
# done with learn: 0.000004 and reg: 0.010000 with acc: 0.389000
# done with learn: 0.000004 and reg: 0.100000 with acc: 0.390000
# done with learn: 0.000004 and reg: 1.000000 with acc: 0.383000
# done with learn: 0.000004 and reg: 10.000000 with acc: 0.376000
# done with learn: 0.000004 and reg: 100.000000 with acc: 0.362000
# done with learn: 0.000004 and reg: 1000.000000 with acc: 0.353000
# done with learn: 0.000004 and reg: 10000.000000 with acc: 0.324000
# done with learn: 0.000005 and reg: 0.000100 with acc: 0.364000
# done with learn: 0.000005 and reg: 0.001000 with acc: 0.356000
# done with learn: 0.000005 and reg: 0.010000 with acc: 0.358000
# done with learn: 0.000005 and reg: 0.100000 with acc: 0.362000
# done with learn: 0.000005 and reg: 1.000000 with acc: 0.398000
# done with learn: 0.000005 and reg: 10.000000 with acc: 0.382000
# done with learn: 0.000005 and reg: 100.000000 with acc: 0.367000
# done with learn: 0.000005 and reg: 1000.000000 with acc: 0.309000
# done with learn: 0.000005 and reg: 10000.000000 with acc: 0.292000
# done with learn: 0.000006 and reg: 0.000100 with acc: 0.364000
# done with learn: 0.000006 and reg: 0.001000 with acc: 0.361000
# done with learn: 0.000006 and reg: 0.010000 with acc: 0.346000
# done with learn: 0.000006 and reg: 0.100000 with acc: 0.357000
# done with learn: 0.000006 and reg: 1.000000 with acc: 0.370000
# done with learn: 0.000006 and reg: 10.000000 with acc: 0.331000
# done with learn: 0.000006 and reg: 100.000000 with acc: 0.306000
# done with learn: 0.000006 and reg: 1000.000000 with acc: 0.339000
# done with learn: 0.000006 and reg: 10000.000000 with acc: 0.218000
# done with learn: 0.000007 and reg: 0.000100 with acc: 0.364000
# done with learn: 0.000007 and reg: 0.001000 with acc: 0.300000
# done with learn: 0.000007 and reg: 0.010000 with acc: 0.342000
# done with learn: 0.000007 and reg: 0.100000 with acc: 0.366000
# done with learn: 0.000007 and reg: 1.000000 with acc: 0.368000
# done with learn: 0.000007 and reg: 10.000000 with acc: 0.353000
# done with learn: 0.000007 and reg: 100.000000 with acc: 0.313000
# done with learn: 0.000007 and reg: 1000.000000 with acc: 0.275000
# done with learn: 0.000007 and reg: 10000.000000 with acc: 0.212000
# done with learn: 0.000008 and reg: 0.000100 with acc: 0.351000
# done with learn: 0.000008 and reg: 0.001000 with acc: 0.339000
# done with learn: 0.000008 and reg: 0.010000 with acc: 0.350000
# done with learn: 0.000008 and reg: 0.100000 with acc: 0.312000
# done with learn: 0.000008 and reg: 1.000000 with acc: 0.334000
# done with learn: 0.000008 and reg: 10.000000 with acc: 0.262000
# done with learn: 0.000008 and reg: 100.000000 with acc: 0.340000
# done with learn: 0.000008 and reg: 1000.000000 with acc: 0.310000
# done with learn: 0.000008 and reg: 10000.000000 with acc: 0.207000
# done with learn: 0.000009 and reg: 0.000100 with acc: 0.283000
# done with learn: 0.000009 and reg: 0.001000 with acc: 0.319000
# done with learn: 0.000009 and reg: 0.010000 with acc: 0.337000
# done with learn: 0.000009 and reg: 0.100000 with acc: 0.299000
# done with learn: 0.000009 and reg: 1.000000 with acc: 0.323000
# done with learn: 0.000009 and reg: 10.000000 with acc: 0.290000
# done with learn: 0.000009 and reg: 100.000000 with acc: 0.294000
# done with learn: 0.000009 and reg: 1000.000000 with acc: 0.303000
# done with learn: 0.000009 and reg: 10000.000000 with acc: 0.183000
# done with learn: 0.000010 and reg: 0.000100 with acc: 0.331000
# done with learn: 0.000010 and reg: 0.001000 with acc: 0.319000
# done with learn: 0.000010 and reg: 0.010000 with acc: 0.295000
# done with learn: 0.000010 and reg: 0.100000 with acc: 0.360000
# done with learn: 0.000010 and reg: 1.000000 with acc: 0.336000
# done with learn: 0.000010 and reg: 10.000000 with acc: 0.336000
# done with learn: 0.000010 and reg: 100.000000 with acc: 0.287000
# done with learn: 0.000010 and reg: 1000.000000 with acc: 0.257000
# done with learn: 0.000010 and reg: 10000.000000 with acc: 0.137000
# lr 4.000000e-07 reg 1.000000e-04 train accuracy: 0.319375 val accuracy: 0.321000
# lr 4.000000e-07 reg 1.000000e-03 train accuracy: 0.322104 val accuracy: 0.331000
# lr 4.000000e-07 reg 1.000000e-02 train accuracy: 0.323625 val accuracy: 0.320000
# lr 4.000000e-07 reg 1.000000e-01 train accuracy: 0.325854 val accuracy: 0.308000
# lr 4.000000e-07 reg 1.000000e+00 train accuracy: 0.320521 val accuracy: 0.321000
# lr 4.000000e-07 reg 1.000000e+01 train accuracy: 0.326896 val accuracy: 0.334000
# lr 4.000000e-07 reg 1.000000e+02 train accuracy: 0.328479 val accuracy: 0.323000
# lr 4.000000e-07 reg 1.000000e+03 train accuracy: 0.391750 val accuracy: 0.385000
# lr 4.000000e-07 reg 1.000000e+04 train accuracy: 0.350187 val accuracy: 0.333000
# lr 5.000000e-07 reg 1.000000e-04 train accuracy: 0.327125 val accuracy: 0.329000
# lr 5.000000e-07 reg 1.000000e-03 train accuracy: 0.330167 val accuracy: 0.316000
# lr 5.000000e-07 reg 1.000000e-02 train accuracy: 0.327562 val accuracy: 0.335000
# lr 5.000000e-07 reg 1.000000e-01 train accuracy: 0.335292 val accuracy: 0.323000
# lr 5.000000e-07 reg 1.000000e+00 train accuracy: 0.334625 val accuracy: 0.343000
# lr 5.000000e-07 reg 1.000000e+01 train accuracy: 0.336313 val accuracy: 0.342000
# lr 5.000000e-07 reg 1.000000e+02 train accuracy: 0.346333 val accuracy: 0.334000
# lr 5.000000e-07 reg 1.000000e+03 train accuracy: 0.398375 val accuracy: 0.376000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.359625 val accuracy: 0.343000
# lr 6.000000e-07 reg 1.000000e-04 train accuracy: 0.337729 val accuracy: 0.337000
# lr 6.000000e-07 reg 1.000000e-03 train accuracy: 0.336625 val accuracy: 0.316000
# lr 6.000000e-07 reg 1.000000e-02 train accuracy: 0.339813 val accuracy: 0.324000
# lr 6.000000e-07 reg 1.000000e-01 train accuracy: 0.337979 val accuracy: 0.330000
# lr 6.000000e-07 reg 1.000000e+00 train accuracy: 0.336438 val accuracy: 0.336000
# lr 6.000000e-07 reg 1.000000e+01 train accuracy: 0.339521 val accuracy: 0.332000
# lr 6.000000e-07 reg 1.000000e+02 train accuracy: 0.355604 val accuracy: 0.343000
# lr 6.000000e-07 reg 1.000000e+03 train accuracy: 0.401583 val accuracy: 0.384000
# lr 6.000000e-07 reg 1.000000e+04 train accuracy: 0.355812 val accuracy: 0.342000
# lr 8.000000e-07 reg 1.000000e-04 train accuracy: 0.352187 val accuracy: 0.346000
# lr 8.000000e-07 reg 1.000000e-03 train accuracy: 0.352563 val accuracy: 0.359000
# lr 8.000000e-07 reg 1.000000e-02 train accuracy: 0.355729 val accuracy: 0.316000
# lr 8.000000e-07 reg 1.000000e-01 train accuracy: 0.355375 val accuracy: 0.352000
# lr 8.000000e-07 reg 1.000000e+00 train accuracy: 0.352833 val accuracy: 0.349000
# lr 8.000000e-07 reg 1.000000e+01 train accuracy: 0.353896 val accuracy: 0.353000
# lr 8.000000e-07 reg 1.000000e+02 train accuracy: 0.370625 val accuracy: 0.360000
# lr 8.000000e-07 reg 1.000000e+03 train accuracy: 0.400646 val accuracy: 0.402000
# lr 8.000000e-07 reg 1.000000e+04 train accuracy: 0.341167 val accuracy: 0.331000
# lr 9.000000e-07 reg 1.000000e-04 train accuracy: 0.353917 val accuracy: 0.358000
# lr 9.000000e-07 reg 1.000000e-03 train accuracy: 0.356208 val accuracy: 0.360000
# lr 9.000000e-07 reg 1.000000e-02 train accuracy: 0.356438 val accuracy: 0.360000
# lr 9.000000e-07 reg 1.000000e-01 train accuracy: 0.360229 val accuracy: 0.351000
# lr 9.000000e-07 reg 1.000000e+00 train accuracy: 0.354458 val accuracy: 0.361000
# lr 9.000000e-07 reg 1.000000e+01 train accuracy: 0.358646 val accuracy: 0.350000
# lr 9.000000e-07 reg 1.000000e+02 train accuracy: 0.381542 val accuracy: 0.363000
# lr 9.000000e-07 reg 1.000000e+03 train accuracy: 0.401250 val accuracy: 0.391000
# lr 9.000000e-07 reg 1.000000e+04 train accuracy: 0.350604 val accuracy: 0.350000
# lr 1.000000e-06 reg 1.000000e-04 train accuracy: 0.361812 val accuracy: 0.353000
# lr 1.000000e-06 reg 1.000000e-03 train accuracy: 0.358687 val accuracy: 0.361000
# lr 1.000000e-06 reg 1.000000e-02 train accuracy: 0.358250 val accuracy: 0.365000
# lr 1.000000e-06 reg 1.000000e-01 train accuracy: 0.359729 val accuracy: 0.337000
# lr 1.000000e-06 reg 1.000000e+00 train accuracy: 0.359000 val accuracy: 0.346000
# lr 1.000000e-06 reg 1.000000e+01 train accuracy: 0.364333 val accuracy: 0.380000
# lr 1.000000e-06 reg 1.000000e+02 train accuracy: 0.381000 val accuracy: 0.379000
# lr 1.000000e-06 reg 1.000000e+03 train accuracy: 0.397146 val accuracy: 0.390000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.349021 val accuracy: 0.355000
# lr 2.000000e-06 reg 1.000000e-04 train accuracy: 0.379188 val accuracy: 0.363000
# lr 2.000000e-06 reg 1.000000e-03 train accuracy: 0.379437 val accuracy: 0.363000
# lr 2.000000e-06 reg 1.000000e-02 train accuracy: 0.380979 val accuracy: 0.368000
# lr 2.000000e-06 reg 1.000000e-01 train accuracy: 0.380417 val accuracy: 0.370000
# lr 2.000000e-06 reg 1.000000e+00 train accuracy: 0.387437 val accuracy: 0.356000
# lr 2.000000e-06 reg 1.000000e+01 train accuracy: 0.388958 val accuracy: 0.369000
# lr 2.000000e-06 reg 1.000000e+02 train accuracy: 0.408833 val accuracy: 0.399000
# lr 2.000000e-06 reg 1.000000e+03 train accuracy: 0.381229 val accuracy: 0.372000
# lr 2.000000e-06 reg 1.000000e+04 train accuracy: 0.343896 val accuracy: 0.333000
# lr 3.000000e-06 reg 1.000000e-04 train accuracy: 0.396062 val accuracy: 0.367000
# lr 3.000000e-06 reg 1.000000e-03 train accuracy: 0.398958 val accuracy: 0.381000
# lr 3.000000e-06 reg 1.000000e-02 train accuracy: 0.394083 val accuracy: 0.373000
# lr 3.000000e-06 reg 1.000000e-01 train accuracy: 0.390937 val accuracy: 0.364000
# lr 3.000000e-06 reg 1.000000e+00 train accuracy: 0.397062 val accuracy: 0.363000
# lr 3.000000e-06 reg 1.000000e+01 train accuracy: 0.400938 val accuracy: 0.365000
# lr 3.000000e-06 reg 1.000000e+02 train accuracy: 0.419292 val accuracy: 0.405000
# lr 3.000000e-06 reg 1.000000e+03 train accuracy: 0.388250 val accuracy: 0.391000
# lr 3.000000e-06 reg 1.000000e+04 train accuracy: 0.326437 val accuracy: 0.340000
# lr 4.000000e-06 reg 1.000000e-04 train accuracy: 0.391750 val accuracy: 0.371000
# lr 4.000000e-06 reg 1.000000e-03 train accuracy: 0.404062 val accuracy: 0.399000
# lr 4.000000e-06 reg 1.000000e-02 train accuracy: 0.396396 val accuracy: 0.389000
# lr 4.000000e-06 reg 1.000000e-01 train accuracy: 0.401979 val accuracy: 0.390000
# lr 4.000000e-06 reg 1.000000e+00 train accuracy: 0.396708 val accuracy: 0.383000
# lr 4.000000e-06 reg 1.000000e+01 train accuracy: 0.399062 val accuracy: 0.376000
# lr 4.000000e-06 reg 1.000000e+02 train accuracy: 0.406146 val accuracy: 0.362000
# lr 4.000000e-06 reg 1.000000e+03 train accuracy: 0.360021 val accuracy: 0.353000
# lr 4.000000e-06 reg 1.000000e+04 train accuracy: 0.318729 val accuracy: 0.324000
# lr 5.000000e-06 reg 1.000000e-04 train accuracy: 0.392479 val accuracy: 0.364000
# lr 5.000000e-06 reg 1.000000e-03 train accuracy: 0.393688 val accuracy: 0.356000
# lr 5.000000e-06 reg 1.000000e-02 train accuracy: 0.396042 val accuracy: 0.358000
# lr 5.000000e-06 reg 1.000000e-01 train accuracy: 0.387750 val accuracy: 0.362000
# lr 5.000000e-06 reg 1.000000e+00 train accuracy: 0.406562 val accuracy: 0.398000
# lr 5.000000e-06 reg 1.000000e+01 train accuracy: 0.405813 val accuracy: 0.382000
# lr 5.000000e-06 reg 1.000000e+02 train accuracy: 0.377417 val accuracy: 0.367000
# lr 5.000000e-06 reg 1.000000e+03 train accuracy: 0.315958 val accuracy: 0.309000
# lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.280687 val accuracy: 0.292000
# lr 6.000000e-06 reg 1.000000e-04 train accuracy: 0.397646 val accuracy: 0.364000
# lr 6.000000e-06 reg 1.000000e-03 train accuracy: 0.376708 val accuracy: 0.361000
# lr 6.000000e-06 reg 1.000000e-02 train accuracy: 0.367563 val accuracy: 0.346000
# lr 6.000000e-06 reg 1.000000e-01 train accuracy: 0.400438 val accuracy: 0.357000
# lr 6.000000e-06 reg 1.000000e+00 train accuracy: 0.399604 val accuracy: 0.370000
# lr 6.000000e-06 reg 1.000000e+01 train accuracy: 0.366250 val accuracy: 0.331000
# lr 6.000000e-06 reg 1.000000e+02 train accuracy: 0.330208 val accuracy: 0.306000
# lr 6.000000e-06 reg 1.000000e+03 train accuracy: 0.347396 val accuracy: 0.339000
# lr 6.000000e-06 reg 1.000000e+04 train accuracy: 0.224542 val accuracy: 0.218000
# lr 7.000000e-06 reg 1.000000e-04 train accuracy: 0.379354 val accuracy: 0.364000
# lr 7.000000e-06 reg 1.000000e-03 train accuracy: 0.350229 val accuracy: 0.300000
# lr 7.000000e-06 reg 1.000000e-02 train accuracy: 0.372250 val accuracy: 0.342000
# lr 7.000000e-06 reg 1.000000e-01 train accuracy: 0.387542 val accuracy: 0.366000
# lr 7.000000e-06 reg 1.000000e+00 train accuracy: 0.376958 val accuracy: 0.368000
# lr 7.000000e-06 reg 1.000000e+01 train accuracy: 0.379833 val accuracy: 0.353000
# lr 7.000000e-06 reg 1.000000e+02 train accuracy: 0.337375 val accuracy: 0.313000
# lr 7.000000e-06 reg 1.000000e+03 train accuracy: 0.288542 val accuracy: 0.275000
# lr 7.000000e-06 reg 1.000000e+04 train accuracy: 0.206021 val accuracy: 0.212000
# lr 8.000000e-06 reg 1.000000e-04 train accuracy: 0.370563 val accuracy: 0.351000
# lr 8.000000e-06 reg 1.000000e-03 train accuracy: 0.384854 val accuracy: 0.339000
# lr 8.000000e-06 reg 1.000000e-02 train accuracy: 0.366854 val accuracy: 0.350000
# lr 8.000000e-06 reg 1.000000e-01 train accuracy: 0.352667 val accuracy: 0.312000
# lr 8.000000e-06 reg 1.000000e+00 train accuracy: 0.377104 val accuracy: 0.334000
# lr 8.000000e-06 reg 1.000000e+01 train accuracy: 0.297958 val accuracy: 0.262000
# lr 8.000000e-06 reg 1.000000e+02 train accuracy: 0.347042 val accuracy: 0.340000
# lr 8.000000e-06 reg 1.000000e+03 train accuracy: 0.316458 val accuracy: 0.310000
# lr 8.000000e-06 reg 1.000000e+04 train accuracy: 0.218896 val accuracy: 0.207000
# lr 9.000000e-06 reg 1.000000e-04 train accuracy: 0.299563 val accuracy: 0.283000
# lr 9.000000e-06 reg 1.000000e-03 train accuracy: 0.339521 val accuracy: 0.319000
# lr 9.000000e-06 reg 1.000000e-02 train accuracy: 0.359854 val accuracy: 0.337000
# lr 9.000000e-06 reg 1.000000e-01 train accuracy: 0.329167 val accuracy: 0.299000
# lr 9.000000e-06 reg 1.000000e+00 train accuracy: 0.356563 val accuracy: 0.323000
# lr 9.000000e-06 reg 1.000000e+01 train accuracy: 0.335729 val accuracy: 0.290000
# lr 9.000000e-06 reg 1.000000e+02 train accuracy: 0.325729 val accuracy: 0.294000
# lr 9.000000e-06 reg 1.000000e+03 train accuracy: 0.274917 val accuracy: 0.303000
# lr 9.000000e-06 reg 1.000000e+04 train accuracy: 0.187375 val accuracy: 0.183000
# lr 1.000000e-05 reg 1.000000e-04 train accuracy: 0.351021 val accuracy: 0.331000
# lr 1.000000e-05 reg 1.000000e-03 train accuracy: 0.338771 val accuracy: 0.319000
# lr 1.000000e-05 reg 1.000000e-02 train accuracy: 0.315229 val accuracy: 0.295000
# lr 1.000000e-05 reg 1.000000e-01 train accuracy: 0.374083 val accuracy: 0.360000
# lr 1.000000e-05 reg 1.000000e+00 train accuracy: 0.348583 val accuracy: 0.336000
# lr 1.000000e-05 reg 1.000000e+01 train accuracy: 0.342062 val accuracy: 0.336000
# lr 1.000000e-05 reg 1.000000e+02 train accuracy: 0.299292 val accuracy: 0.287000
# lr 1.000000e-05 reg 1.000000e+03 train accuracy: 0.241813 val accuracy: 0.257000
# lr 1.000000e-05 reg 1.000000e+04 train accuracy: 0.151208 val accuracy: 0.137000
# best validation accuracy achieved during validation: 0.405000

# %%
softmax = Softmax()
loss_hist = softmax.train(X_train, y_train, learning_rate=3e-6, reg= 1e4, 
                      num_iters=10, verbose=False)
val_acc = np.mean(y_val == softmax.predict(X_val))
print(val_acc)
# Out:
# 0.196

# %%
# Visualize the validation results
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')

plt.tight_layout()
plt.show()

# %%
# if you want to take a look at the other classifiers assign them to best_softmax here
sorted_classifiers = sorted(all_classifiers, key=lambda x : x[1])
best_softmax = sorted_classifiers[-1][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-157-745c3c1870e0> in <module>()
#       1 # if you want to take a look at the other classifiers assign them to best_softmax here
#       2 sorted_classifiers = sorted(all_classifiers, key=lambda x : x[1])
# ----> 3 best_softmax = sorted_classifiers[-1][0]
#
# IndexError: list index out of range

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.401000

# %%
# Visualize the learned weights for each class
#best_softmax = sorted_classifiers[idx][0]
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
  plt.subplot(2, 5, i + 1)

  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Inline Question</h3>
#     <p>Describe what your visualized Softmax weights look like.</p>
# </div>

# %% [markdown]
# ## Save the model
#
# When you are satisfied with your training, save the model for submission.
#
# <div class="alert alert-danger">
#     <h3>Warning</h3>
#     <p>You might get an error like this:</p>
#     <p>PicklingError: Can't pickle `<class 'dl4cv.classifiers.linear_classifier.Softmax'>`: it's not the same object as dl4cv.classifiers.linear_classifier.Softmax</p>
#     <p>The reason is that we are using autoreload and working on this class during the notebook session. If you get this error simply restart the kernel and rerun the whole script (Kernel -> Restart & Run All) or only the important cells for generating your model.</p>
# </div>

# %%
from dl4cv.model_savers import save_softmax_classifier
from dl4cv.classifiers import Softmax

save_softmax_classifier(best_softmax)

# %% [markdown]
# ## Scoring function
# We will score the model you have just saved based on the classification accuracy on our test dataset. The scoring function should represent the difficulty of obtaining a good test accuracy and should therefore give 0 points for worse results than random guessing, should be linear in a first regime and exponential beyond that. The onset of exponential growth depends on the problem. In that region you get twice as many points for an additional 10% accuracy.
#
# For this problem we specifically use the following scoring function:
#
# $$f(x) = \left\{
# 	\begin{array}{ll}
# 		0  & \mbox{if } x \leq 0.1 \\
# 		100x & \mbox{if } 0.1 < x \leq 0.38 \\
#         \left(\frac{38}{\exp(0.38 \ln(2)/0.1)}\right) \exp(x \ln(2)/0.1) & \mbox{if } 0.38 < x \leq 1
# 	\end{array}
# \right.$$
#
# The function can be plotted in the following cell.

# %%
from dl4cv.data_utils import scoring_function

x = np.linspace(0, 1, num=1000)
plt.plot(x, scoring_function(x, lin_exp_boundary=0.38, doubling_rate=0.1))
plt.title('Scoring Function')
plt.xlabel('Test Accuracy')
plt.ylabel('Score')
plt.show()
